# %% [markdown]
# # Bank Marketing Data Set Group Project Proposal
# ##### By: Alex Khadra, Shay Tannne, Liam Buchan, Tanaya Parakh

# %% [markdown]
# ### Introduction:
# The data set we are working on is the bank marketing data set. The bank we are analyzing is a Portuguese banking institution with data related with direct marketing campaigns (phone calls).
#
# A term deposit is a cash investment, where your money is invested for an agreed rate of interest over a fixed amount of time, or term.
#
# Our data set includes:
# - `age` - Age
# - `job` - Type of job
# - `marital` - Marital status
# - `education` - Level of education
# - `default` - Has credit in default?
# - `housing` - Has housing loan?
# - `loan` - Has personal loan?
# - `contact` - Contact communication type
# - `month` - Last contact month of year
# - `day_of_week` - Last contact day of the week
# - `duration` - Last contact duration, in seconds
# - `campaign` - Number of contacts performed during this campaign and for this client
# - `pdays` - Number of days that passed by after the client was last contacted from a previous campaign
# - `previous` - Number of contacts performed before this campaign and for this client
# - `poutcome` - Outcome of the previous marketing campaign
# - `y` - Has the client subscribed a term deposit?
#
# Throughout the project we will look at all the variables and see how they relate to clients subscribing to a term deposit. We will than find which variables have the greatest influence on predicting whether or not a client will subscribe a term deposit.

# %% [markdown]
# ## Wrangling + preliminary analysis

# %% [markdown]
# To be able to preform all the same functions we used throughout this project, these libraries must be installed:

# %%
library(tidyverse)
library(repr)
library(rvest)
library(stringr)
library(tidymodels)

# %%
bank_all_cols <- read_delim("data/bank-full.csv", delim = ';')
bank_all_cols
# Out:
# Parsed with column specification:
# cols(
#   age = col_double(),
#   job = col_character(),
#   marital = col_character(),
#   education = col_character(),
#   default = col_character(),
#   balance = col_double(),
#   housing = col_character(),
#   loan = col_character(),
#   contact = col_character(),
#   day = col_double(),
#   month = col_character(),
#   duration = col_double(),
#   campaign = col_double(),
#   pdays = col_double(),
#   previous = col_double(),
#   poutcome = col_character(),
#   y = col_character()
# )
#       age job           marital  education default balance housing loan
# 1     58  management    married  tertiary  no      2143    yes     no
# 2     44  technician    single   secondary no        29    yes     no
# 3     33  entrepreneur  married  secondary no         2    yes     yes
# 4     47  blue-collar   married  unknown   no      1506    yes     no
# 5     33  unknown       single   unknown   no         1    no      no
# 6     35  management    married  tertiary  no       231    yes     no
# 7     28  management    single   tertiary  no       447    yes     yes
# 8     42  entrepreneur  divorced tertiary  yes        2    yes     no
# 9     58  retired       married  primary   no       121    yes     no
# 10    43  technician    single   secondary no       593    yes     no
# 11    41  admin.        divorced secondary no       270    yes     no
# 12    29  admin.        single   secondary no       390    yes     no
# 13    53  technician    married  secondary no         6    yes     no
# 14    58  technician    married  unknown   no        71    yes     no
# 15    57  services      married  secondary no       162    yes     no
# 16    51  retired       married  primary   no       229    yes     no
# 17    45  admin.        single   unknown   no        13    yes     no
# 18    57  blue-collar   married  primary   no        52    yes     no
# 19    60  retired       married  primary   no        60    yes     no
# 20    33  services      married  secondary no         0    yes     no
# 21    28  blue-collar   married  secondary no       723    yes     yes
# 22    56  management    married  tertiary  no       779    yes     no
# 23    32  blue-collar   single   primary   no        23    yes     yes
# 24    25  services      married  secondary no        50    yes     no
# 25    40  retired       married  primary   no         0    yes     yes
# 26    44  admin.        married  secondary no      -372    yes     no
# 27    39  management    single   tertiary  no       255    yes     no
# 28    52  entrepreneur  married  secondary no       113    yes     yes
# 29    46  management    single   secondary no      -246    yes     no
# 30    36  technician    single   secondary no       265    yes     yes
# ⋮     ⋮   ⋮             ⋮        ⋮         ⋮       ⋮       ⋮       ⋮
# 45182 46  blue-collar   married  secondary no      6879    no      no
# 45183 34  technician    married  secondary no       133    no      no
# 45184 70  retired       married  primary   no       324    no      no
# 45185 63  retired       married  secondary no      1495    no      no
# 45186 60  services      married  tertiary  no      4256    yes     no
# 45187 59  unknown       married  unknown   no      1500    no      no
# 45188 32  services      single   secondary no      1168    yes     no
# 45189 29  management    single   secondary no       703    yes     no
# 45190 25  services      single   secondary no       199    no      no
# 45191 32  blue-collar   married  secondary no       136    no      no
# 45192 75  retired       divorced tertiary  no      3810    yes     no
# 45193 29  management    single   tertiary  no       765    no      no
# 45194 28  self-employed single   tertiary  no       159    no      no
# 45195 59  management    married  tertiary  no       138    yes     yes
# 45196 68  retired       married  secondary no      1146    no      no
# 45197 25  student       single   secondary no       358    no      no
# 45198 36  management    single   secondary no      1511    yes     no
# 45199 37  management    married  tertiary  no      1428    no      no
# 45200 34  blue-collar   single   secondary no      1475    yes     no
# 45201 38  technician    married  secondary no       557    yes     no
# 45202 53  management    married  tertiary  no       583    no      no
# 45203 34  admin.        single   secondary no       557    no      no
# 45204 23  student       single   tertiary  no       113    no      no
# 45205 73  retired       married  secondary no      2850    no      no
# 45206 25  technician    single   secondary no       505    no      yes
# 45207 51  technician    married  tertiary  no       825    no      no
# 45208 71  retired       divorced primary   no      1729    no      no
# 45209 72  retired       married  secondary no      5715    no      no
# 45210 57  blue-collar   married  secondary no       668    no      no
# 45211 37  entrepreneur  married  secondary no      2971    no      no
#       contact   day month duration campaign pdays previous poutcome y
# 1     unknown   5   may   261      1        -1    0        unknown  no
# 2     unknown   5   may   151      1        -1    0        unknown  no
# 3     unknown   5   may    76      1        -1    0        unknown  no
# 4     unknown   5   may    92      1        -1    0        unknown  no
# 5     unknown   5   may   198      1        -1    0        unknown  no
# 6     unknown   5   may   139      1        -1    0        unknown  no
# 7     unknown   5   may   217      1        -1    0        unknown  no
# 8     unknown   5   may   380      1        -1    0        unknown  no
# 9     unknown   5   may    50      1        -1    0        unknown  no
# 10    unknown   5   may    55      1        -1    0        unknown  no
# 11    unknown   5   may   222      1        -1    0        unknown  no
# 12    unknown   5   may   137      1        -1    0        unknown  no
# 13    unknown   5   may   517      1        -1    0        unknown  no
# 14    unknown   5   may    71      1        -1    0        unknown  no
# 15    unknown   5   may   174      1        -1    0        unknown  no
# 16    unknown   5   may   353      1        -1    0        unknown  no
# 17    unknown   5   may    98      1        -1    0        unknown  no
# 18    unknown   5   may    38      1        -1    0        unknown  no
# 19    unknown   5   may   219      1        -1    0        unknown  no
# 20    unknown   5   may    54      1        -1    0        unknown  no
# 21    unknown   5   may   262      1        -1    0        unknown  no
# 22    unknown   5   may   164      1        -1    0        unknown  no
# 23    unknown   5   may   160      1        -1    0        unknown  no
# 24    unknown   5   may   342      1        -1    0        unknown  no
# 25    unknown   5   may   181      1        -1    0        unknown  no
# 26    unknown   5   may   172      1        -1    0        unknown  no
# 27    unknown   5   may   296      1        -1    0        unknown  no
# 28    unknown   5   may   127      1        -1    0        unknown  no
# 29    unknown   5   may   255      2        -1    0        unknown  no
# 30    unknown   5   may   348      1        -1    0        unknown  no
# ⋮     ⋮         ⋮   ⋮     ⋮        ⋮        ⋮     ⋮        ⋮        ⋮
# 45182 cellular  15  nov     74     2        118    3       failure  no
# 45183 cellular  15  nov    401     2        187    5       success  yes
# 45184 cellular  15  nov     78     1         96    7       success  no
# 45185 cellular  16  nov    138     1         22    5       success  no
# 45186 cellular  16  nov    200     1         92    4       success  yes
# 45187 cellular  16  nov    280     1        104    2       failure  no
# 45188 cellular  16  nov    411     1         -1    0       unknown  yes
# 45189 cellular  16  nov    236     1        550    2       success  yes
# 45190 cellular  16  nov    173     1         92    5       failure  no
# 45191 cellular  16  nov    206     1        188    3       success  yes
# 45192 cellular  16  nov    262     1        183    1       failure  yes
# 45193 cellular  16  nov    238     1         -1    0       unknown  yes
# 45194 cellular  16  nov    449     2         33    4       success  yes
# 45195 cellular  16  nov    162     2        187    5       failure  no
# 45196 cellular  16  nov    212     1        187    6       success  yes
# 45197 cellular  16  nov    330     1         -1    0       unknown  yes
# 45198 cellular  16  nov    270     1         -1    0       unknown  yes
# 45199 cellular  16  nov    333     2         -1    0       unknown  no
# 45200 cellular  16  nov   1166     3        530   12       other    no
# 45201 cellular  16  nov   1556     4         -1    0       unknown  yes
# 45202 cellular  17  nov    226     1        184    4       success  yes
# 45203 cellular  17  nov    224     1         -1    0       unknown  yes
# 45204 cellular  17  nov    266     1         -1    0       unknown  yes
# 45205 cellular  17  nov    300     1         40    8       failure  yes
# 45206 cellular  17  nov    386     2         -1    0       unknown  yes
# 45207 cellular  17  nov    977     3         -1    0       unknown  yes
# 45208 cellular  17  nov    456     2         -1    0       unknown  yes
# 45209 cellular  17  nov   1127     5        184    3       success  yes
# 45210 telephone 17  nov    508     4         -1    0       unknown  no
# 45211 cellular  17  nov    361     2        188   11       other    no

# %%
bank_all <- bank_all_cols %>%
    select(-c(default, contact, duration))
bank_all
#Please refer to "Methods" section to see why we preformed the select function
# Out:
#       age job           marital  education balance housing loan day month
# 1     58  management    married  tertiary  2143    yes     no   5   may
# 2     44  technician    single   secondary   29    yes     no   5   may
# 3     33  entrepreneur  married  secondary    2    yes     yes  5   may
# 4     47  blue-collar   married  unknown   1506    yes     no   5   may
# 5     33  unknown       single   unknown      1    no      no   5   may
# 6     35  management    married  tertiary   231    yes     no   5   may
# 7     28  management    single   tertiary   447    yes     yes  5   may
# 8     42  entrepreneur  divorced tertiary     2    yes     no   5   may
# 9     58  retired       married  primary    121    yes     no   5   may
# 10    43  technician    single   secondary  593    yes     no   5   may
# 11    41  admin.        divorced secondary  270    yes     no   5   may
# 12    29  admin.        single   secondary  390    yes     no   5   may
# 13    53  technician    married  secondary    6    yes     no   5   may
# 14    58  technician    married  unknown     71    yes     no   5   may
# 15    57  services      married  secondary  162    yes     no   5   may
# 16    51  retired       married  primary    229    yes     no   5   may
# 17    45  admin.        single   unknown     13    yes     no   5   may
# 18    57  blue-collar   married  primary     52    yes     no   5   may
# 19    60  retired       married  primary     60    yes     no   5   may
# 20    33  services      married  secondary    0    yes     no   5   may
# 21    28  blue-collar   married  secondary  723    yes     yes  5   may
# 22    56  management    married  tertiary   779    yes     no   5   may
# 23    32  blue-collar   single   primary     23    yes     yes  5   may
# 24    25  services      married  secondary   50    yes     no   5   may
# 25    40  retired       married  primary      0    yes     yes  5   may
# 26    44  admin.        married  secondary -372    yes     no   5   may
# 27    39  management    single   tertiary   255    yes     no   5   may
# 28    52  entrepreneur  married  secondary  113    yes     yes  5   may
# 29    46  management    single   secondary -246    yes     no   5   may
# 30    36  technician    single   secondary  265    yes     yes  5   may
# ⋮     ⋮   ⋮             ⋮        ⋮         ⋮       ⋮       ⋮    ⋮   ⋮
# 45182 46  blue-collar   married  secondary 6879    no      no   15  nov
# 45183 34  technician    married  secondary  133    no      no   15  nov
# 45184 70  retired       married  primary    324    no      no   15  nov
# 45185 63  retired       married  secondary 1495    no      no   16  nov
# 45186 60  services      married  tertiary  4256    yes     no   16  nov
# 45187 59  unknown       married  unknown   1500    no      no   16  nov
# 45188 32  services      single   secondary 1168    yes     no   16  nov
# 45189 29  management    single   secondary  703    yes     no   16  nov
# 45190 25  services      single   secondary  199    no      no   16  nov
# 45191 32  blue-collar   married  secondary  136    no      no   16  nov
# 45192 75  retired       divorced tertiary  3810    yes     no   16  nov
# 45193 29  management    single   tertiary   765    no      no   16  nov
# 45194 28  self-employed single   tertiary   159    no      no   16  nov
# 45195 59  management    married  tertiary   138    yes     yes  16  nov
# 45196 68  retired       married  secondary 1146    no      no   16  nov
# 45197 25  student       single   secondary  358    no      no   16  nov
# 45198 36  management    single   secondary 1511    yes     no   16  nov
# 45199 37  management    married  tertiary  1428    no      no   16  nov
# 45200 34  blue-collar   single   secondary 1475    yes     no   16  nov
# 45201 38  technician    married  secondary  557    yes     no   16  nov
# 45202 53  management    married  tertiary   583    no      no   17  nov
# 45203 34  admin.        single   secondary  557    no      no   17  nov
# 45204 23  student       single   tertiary   113    no      no   17  nov
# 45205 73  retired       married  secondary 2850    no      no   17  nov
# 45206 25  technician    single   secondary  505    no      yes  17  nov
# 45207 51  technician    married  tertiary   825    no      no   17  nov
# 45208 71  retired       divorced primary   1729    no      no   17  nov
# 45209 72  retired       married  secondary 5715    no      no   17  nov
# 45210 57  blue-collar   married  secondary  668    no      no   17  nov
# 45211 37  entrepreneur  married  secondary 2971    no      no   17  nov
#       campaign pdays previous poutcome y
# 1     1        -1    0        unknown  no
# 2     1        -1    0        unknown  no
# 3     1        -1    0        unknown  no
# 4     1        -1    0        unknown  no
# 5     1        -1    0        unknown  no
# 6     1        -1    0        unknown  no
# 7     1        -1    0        unknown  no
# 8     1        -1    0        unknown  no
# 9     1        -1    0        unknown  no
# 10    1        -1    0        unknown  no
# 11    1        -1    0        unknown  no
# 12    1        -1    0        unknown  no
# 13    1        -1    0        unknown  no
# 14    1        -1    0        unknown  no
# 15    1        -1    0        unknown  no
# 16    1        -1    0        unknown  no
# 17    1        -1    0        unknown  no
# 18    1        -1    0        unknown  no
# 19    1        -1    0        unknown  no
# 20    1        -1    0        unknown  no
# 21    1        -1    0        unknown  no
# 22    1        -1    0        unknown  no
# 23    1        -1    0        unknown  no
# 24    1        -1    0        unknown  no
# 25    1        -1    0        unknown  no
# 26    1        -1    0        unknown  no
# 27    1        -1    0        unknown  no
# 28    1        -1    0        unknown  no
# 29    2        -1    0        unknown  no
# 30    1        -1    0        unknown  no
# ⋮     ⋮        ⋮     ⋮        ⋮        ⋮
# 45182 2        118    3       failure  no
# 45183 2        187    5       success  yes
# 45184 1         96    7       success  no
# 45185 1         22    5       success  no
# 45186 1         92    4       success  yes
# 45187 1        104    2       failure  no
# 45188 1         -1    0       unknown  yes
# 45189 1        550    2       success  yes
# 45190 1         92    5       failure  no
# 45191 1        188    3       success  yes
# 45192 1        183    1       failure  yes
# 45193 1         -1    0       unknown  yes
# 45194 2         33    4       success  yes
# 45195 2        187    5       failure  no
# 45196 1        187    6       success  yes
# 45197 1         -1    0       unknown  yes
# 45198 1         -1    0       unknown  yes
# 45199 2         -1    0       unknown  no
# 45200 3        530   12       other    no
# 45201 4         -1    0       unknown  yes
# 45202 1        184    4       success  yes
# 45203 1         -1    0       unknown  yes
# 45204 1         -1    0       unknown  yes
# 45205 1         40    8       failure  yes
# 45206 2         -1    0       unknown  yes
# 45207 3         -1    0       unknown  yes
# 45208 2         -1    0       unknown  yes
# 45209 5        184    3       success  yes
# 45210 4         -1    0       unknown  no
# 45211 2        188   11       other    no

# %%
bank_split <- initial_split(bank_all, prop = 0.75, strata = y)
cancer_train <- training(bank_split)
cancer_test <- testing(bank_split)

# %%
#To summarize the data in a table we use the summary function 
print("Summary Table")
summary(cancer_train)
# Out:
# [1] "Summary Table"
#       age            job              marital           education
#  Min.   :18.00   Length:33909       Length:33909       Length:33909
#  1st Qu.:33.00   Class :character   Class :character   Class :character
#  Median :39.00   Mode  :character   Mode  :character   Mode  :character
#  Mean   :40.98
#  3rd Qu.:48.00
#  Max.   :95.00
#     balance         housing              loan                day
#  Min.   : -8019   Length:33909       Length:33909       Min.   : 1.00
#  1st Qu.:    71   Class :character   Class :character   1st Qu.: 8.00
#  Median :   449   Mode  :character   Mode  :character   Median :16.00
#  Mean   :  1371                                         Mean   :15.81
#  3rd Qu.:  1432                                         3rd Qu.:21.00
#  Max.   :102127                                         Max.   :31.00
#     month              campaign          pdays           previous
#  Length:33909       Min.   : 1.000   Min.   : -1.00   Min.   : 0.0000
#  Class :character   1st Qu.: 1.000   1st Qu.: -1.00   1st Qu.: 0.0000
#  Mode  :character   Median : 2.000   Median : -1.00   Median : 0.0000
#                     Mean   : 2.777   Mean   : 40.16   Mean   : 0.5746
#                     3rd Qu.: 3.000   3rd Qu.: -1.00   3rd Qu.: 0.0000
#                     Max.   :63.000   Max.   :871.00   Max.   :58.0000
#    poutcome              y
#  Length:33909       Length:33909
#  Class :character   Class :character
#  Mode  :character   Mode  :character

# %% [markdown]
# Throughout our project, we will be comparing different variables to see if the client subscribed a term deposit. But before we do that, we will compare the other variables with each other. For example, if we use balance and education to determine whether or not a client subscribes, we will first compare education and balance. If education and balance are positively related they should both be related to the client subscribing in the same way. If they are negatively related the should relate to the client subscribed in opposite ways. In our graph we will take a look at the relationship between balance and education.

# %%
balance_vs_education <- ggplot(bank_all, aes(x = education, y = balance)) +
  geom_boxplot() +
  labs(x = "Education", y = "Balance")
balance_vs_education
# Out:
# plot without title

# %% [markdown]
# From our boxplot, we can see that the balance is similar for all levels of education.

# %% [markdown]
# We also see if there is a relationship between age and balance. Since these are two quantitative variables we do not use a boxplot but instead a scatterplot.

# %%
balance_vs_age <- ggplot(bank_all, aes(x = age, y = balance)) +
  geom_point() +
  labs(x = "Age", y = "Balance")
balance_vs_age
# Out:
# plot without title

# %% [markdown]
# From this graph we see that there may be a relation but that the relationship is not linear.

# %% [markdown]
# ### Method
#
# When refering to bank_all we can see that we filtered out the columns we thought would not play any relationship to whether or not a client subscribed a term deposit. The columns we did not include are default, contact, duration. We will consider all other columns as they may have a relationship with clients subscribing. We will compare all the other columns to clients subscribing. We will figure out the relationship (if any) through various graphs. These graphs depend on whether or not the predictor is a quantitative variable or a qualitative variable. We will than use the Kth nearest algorithm to predict the cases in our testing data. To come up with the best K value, we will perform a vfold on our training data.

# %% [markdown]
# ### Expected outcomes and significance

# %% [markdown]
# From our project we expect to find a few relationships. First, we expect that balance and education both have a positive relationship on whether or not clients subscribe. We also believe that the peak age for subscribing will be around 35-40 years of age and that married couples tend to subscribe more often than singles. These impacts could change the marketing and advertising of term deposit to show that it does not require a certain amount of money or that you can start at any age. These findings could lead to further questions such as "Do married couples tend to be more financial responsible than singles?" or "At what age do people tend to care about their money the most?" Many further questions can be analyzed after this project.
